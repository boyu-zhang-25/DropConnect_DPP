# %%
import numpy as np

# %%
# dict_key = percentage of parameters ---> value = accuracy
node_without_drop_without_rewt ={5:[11.68,12.60,17.57,17.67,17.67,17.08],
                                 10:[27.97,19.13,22.68,25.87,20.32],
                                 15:[26.29,36.96,33.19,27.96,25.04],
                                 20:[30.03,43.71,24.50,30.90,26.30]
                                }
node_with_drop_without_rewt ={5:[18.78,9.69,9.50,17.48,8.96],
                              10:[34.72,28.52,14.60,31.14,15.91],
                              15:[39.04,29.24,31.81,21.89,26.72],
                              20:[42.87,35.51,31.48,35.17,24.39]
    
}
node_without_drop_with_rewt ={5:[87.37,83.45,85.95,84.83,85.56],
                              10:[91.98,92.44,92.67,93.92,92.58],
                              15:[95.25,94.94,94.78,95.19,95.50],
                              20:[95.91,96.30,95.77,95.77,95.77,95.85]
                             }
                              
node_with_drop_with_rewt ={5:[79.07,80.43,83.91,84.63,85.28],
                           10:[92.98,92.48,91.36,93.17,93.07],
                           15:[96.11,95.64,94.78,95.25,95.59],
                           20:[96.53,96.84,96.71,96.66,96.75]
                          }

# %%
# dict_key = percentage of parameters ---> value = accuracy
edge_without_drop_without_rewt ={5:[19.62,17.78,19.07,15.54,20.03],
                                 10:[27.56,22.00,30.52,29.81,29.89],
                                 15:[41.57,38.65,41.51,40.79,38.71],
                                 20:[49.10,52.62,54.34,46.34,52.97]
                                 
                                }
edge_with_drop_without_rewt ={5:[21.69,24.13,31.83,22.05,22.23],
                              10:[42.66,34.48,40.21,42.05,36.72],
                              15:[50.34,48.32,48.54,49.07,49.78],
                              20:[67.52,63.18,65.08,64.79,62.63]
    
                            }
edge_without_drop_with_rewt ={5:[71.29,69.28,73.65,74.32,72.54],
                              10:[94.70,94.52,94.51,94.36,94.19],
                              15:[96.90,96.83,96.91,96.78,96.55],
                              20:[97.23,97.33,97.22,97.36,97.47]
                             }
                              
edge_with_drop_with_rewt ={5:[75.32,78.42,79.29,77.07,73],
                           10:[94.68,94.64,94.92,94.94,94.75],
                           15:[96.82,97.,96.85,97.11,97.05,],
                           20:[97.78,97.75,97.75,97.75,97.86,97.71]
                          }

# %%
hi_node_without_drop_without_rewt ={30:[40.56,40.98,40.42,44.78,43.53],
                                    40:[53.25,57.51,56.45,52.35,52.78],
                                    50:[63.43,59.87,67.18,63.82,61.67],
                                    60:[83.82,79.77,85.77,83.88,82.03],
                                    70:[95.51,94.86,93.02,92.03,93.26],
                                    80:[94.78,95.70,96.44,95.75,96.58]
                                 
                                }
hi_node_with_drop_without_rewt ={30:[45.28,46.96,47.22,46.93,42.22],
                                 40:[51.16,50.07,52.11,53.79,51.89],
                                 50:[63.08,59.04,70.49,74.93,66.41],
                                 60:[78.60,83.10,85.95,79.65,79.46],
                                 70:[92.03,92.65,91.98,93.26,89.13],
                                 80:[95.57,95.7,96.83,95.77,95.31]
                                 
    
}
hi_node_without_drop_with_rewt ={30:[96.71,97.03,97.10,97.02,97.13],
                              40:[97.38,97.36,97.42,97.37,97.58,97.30],
                              50:[98.46,97.54,97.58,97.54,97.52],
                              60:[97.59,97.61,97.62,97.72,97.67],
                              70:[97.68,97.88,97.81,97.75,97.78],
                              80:[97.79,97.76,97.85,97.85,97.85]
                             }
                              
hi_node_with_drop_with_rewt ={30:[97.,97.58,97.72,97.38,97.54],
                           40:[97.94,97.95,97.89,98.07,97.83,97.78],
                           50:[97.98,97.99,98.07,98.08,98.07,98.17],
                           60:[98.18,98.18,98.17,98.09,98.17,98.19],
                           70:[98.08,98.09,98.22,98.25,98.27],
                           80:[98.29,98.29,98.27,98.27,98.24]
                          }

# %%
hi_edge_without_drop_without_rewt ={30:[72.40,77.32,73.30,75.14,75.86],
                                 40:[86.,88.13,82.53,89.14,88.29,87.58],
                                 50:[94.,93.9],
                                 60:[95.,95.4],
                                 70:[97.,96.96],
                                 80:[97.57]
                                 
                                 
                                }
hi_edge_with_drop_without_rewt ={30:[80.90,79.19,78.46,80.28,82.06],
                              40:[89.69,88.67,91.98,91.37,90.07],
                              50:[95.08,95.97],
                              60:[96.26,97.10],
                              70:97.28,
                              80:97.93
                              
    
                            }
hi_edge_without_drop_with_rewt ={30:[98.,97.64,97.70,97.79,97.65,97.70],
                              40:[98.,97.84,97.92,97.85,97.86,97.90],
                              50:[98.,98.12,97.85,97.86],
                              60:[98.,98.01],
                              70:[98.,98.06],
                              80:[98.,97.91]
                             }
                              
hi_edge_with_drop_with_rewt ={ 30:[98.17,98.15,98.10,98.10,98.14],
                              40:[98.17,98.21,98.22,98.22,98.22],
                              50:[98.22,98.19],
                              60:98.31,
                              70:98.29,
                              80:98.29
                          }

# %%
# %who
# Out:
# edge_with_drop_with_rewt	 edge_with_drop_without_rewt	 edge_without_drop_with_rewt	 edge_without_drop_without_rewt	 hi_edge_with_drop_with_rewt	 hi_edge_with_drop_without_rewt	 hi_edge_without_drop_with_rewt	 hi_edge_without_drop_without_rewt	 hi_node_with_drop_with_rewt
# hi_node_with_drop_without_rewt	 hi_node_without_drop_with_rewt	 hi_node_without_drop_without_rewt	 node_with_drop_with_rewt	 node_with_drop_without_rewt	 node_without_drop_with_rewt	 node_without_drop_without_rewt	 np

# %%
#dppEdge percentage to edge
# percentage = [5,10,15,  20,30,  40, 50, 60, 70, 80]
# edges =      30 69 109 148 228 307 387 466 545 625

# %%
percentage = [5,10,15,20,30,40,50,60,70,80]

node_without_rewt = []
node_dropout_without_rewt=[]
node_rewt = []
node_dropout_rewt=[]

edge_without_rewt = []
edge_dropout_without_rewt=[]
edge_rewt = []
edge_dropout_rewt=[]

node_without_rewt_std = []
node_dropout_without_rewt_std=[]
node_rewt_std = []
node_dropout_rewt_std = []

edge_without_rewt_std = []
edge_dropout_without_rewt_std =[]
edge_rewt_std = []
edge_dropout_rewt_std = []

for p in [5,10,15,20]:
        temp = np.array(node_without_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_without_rewt.append(mean)
        node_without_rewt_std.append(np.std(temp))
for p in [5,10,15,20]:
        temp = np.array(node_with_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_dropout_without_rewt.append(mean)
        node_dropout_without_rewt_std.append(np.std(temp))
for p in [5,10,15,20]:
        temp = np.array(node_without_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_rewt.append(mean)
        node_rewt_std.append(np.std(temp))
for p in [5,10,15,20]:
        temp = np.array(node_with_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_dropout_rewt.append(mean)
        node_dropout_rewt_std.append(np.std(temp))
        

for p in [5,10,15,20]:
        temp = np.array(edge_without_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_without_rewt.append(mean)
        edge_without_rewt_std.append(np.std(temp))
for p in [5,10,15,20]:
        temp = np.array(edge_with_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_dropout_without_rewt.append(mean)
        edge_dropout_without_rewt_std.append(np.std(temp))
for p in [5,10,15,20]:
        temp = np.array(edge_without_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_rewt.append(mean)
        edge_rewt_std.append(np.std(temp))
for p in [5,10,15,20]:
        temp = np.array(edge_with_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_dropout_rewt.append(mean)
        edge_dropout_rewt_std.append(np.std(temp))
        
        
for p in [30,40,50,60,70,80]:
        temp = np.array(hi_node_without_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_without_rewt.append(mean)
        node_without_rewt_std.append(np.std(temp))
for p in [30,40,50,60,70,80]:
        temp = np.array(hi_node_with_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_dropout_without_rewt.append(mean)
        node_dropout_without_rewt_std.append(np.std(temp))
for p in [30,40,50,60,70,80]:
        temp = np.array(hi_node_without_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_rewt.append(mean)
        node_rewt_std.append(np.std(temp))
for p in [30,40,50,60,70,80]:
        temp = np.array(hi_node_with_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        node_dropout_rewt.append(mean)
        node_dropout_rewt_std.append(np.std(temp))
        

for p in [30,40,50,60,70,80]:
        temp = np.array(hi_edge_without_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_without_rewt.append(mean)
        edge_without_rewt_std.append(np.std(temp))
for p in [30,40,50,60,70,80]:
        temp = np.array(hi_edge_with_drop_without_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_dropout_without_rewt.append(mean)
        edge_dropout_without_rewt_std.append(np.std(temp))
for p in [30,40,50,60,70,80]:
        temp = np.array(hi_edge_without_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_rewt.append(mean)
        edge_rewt_std.append(np.std(temp))
for p in [30,40,50,60,70,80]:
        temp = np.array(hi_edge_with_drop_with_rewt[p])
        temp = 1 - temp/100
        mean = np.mean(temp)
        edge_dropout_rewt.append(mean)
        edge_dropout_rewt_std.append(np.std(temp))
        
        
percentage = [5,10,15,20,30,40,50,60,70,80]
# node_without_rewt = 1-np.array(node_without_rewt)/100
# node_dropout_without_rewt=1-np.array(node_dropout_without_rewt)/100
# node_rewt = 1-np.array(node_rewt)/100
# node_dropout_rewt=1-np.array(node_dropout_rewt)/100

# edge_without_rewt = 1-np.array(edge_without_rewt)/100
# edge_dropout_without_rewt= 1-np.array(edge_dropout_without_rewt)/100
# edge_rewt = 1-np.array(edge_rewt)/100
# edge_dropout_rewt=1-np.array(edge_dropout_rewt)/100

print(node_without_rewt, len(node_without_rewt), len(node_without_rewt_std))
print(node_rewt, len(node_rewt), len(node_rewt_std))
print(node_dropout_without_rewt, len(node_dropout_without_rewt),len(node_dropout_without_rewt_std))
print(node_dropout_rewt, len(node_dropout_rewt),len(node_dropout_rewt_std))
print(edge_without_rewt, len(edge_without_rewt))
print(edge_rewt, len(edge_rewt))
print(edge_dropout_without_rewt, len(edge_dropout_without_rewt))
print(edge_dropout_rewt, len(edge_dropout_rewt))
# Out:
# [0.8428833333333333, 0.76806, 0.7011200000000001, 0.68912, 0.5794600000000001, 0.45532000000000006, 0.36805999999999994, 0.16946000000000003, 0.06263999999999999, 0.0415] 10 10
# [0.14567999999999998, 0.07282, 0.048680000000000015, 0.04105000000000003, 0.030020000000000026, 0.02598333333333332, 0.022720000000000008, 0.02358, 0.022199999999999977, 0.02180000000000002] 10 10
# [0.8711800000000001, 0.75022, 0.7026000000000001, 0.66116, 0.5427799999999999, 0.48196000000000006, 0.3321, 0.18648, 0.08189999999999995, 0.04164000000000001] 10 10
# [0.17336000000000001, 0.07387999999999999, 0.04525999999999999, 0.03301999999999998, 0.025560000000000006, 0.02090000000000003, 0.01940000000000003, 0.018366666666666625, 0.01818000000000002, 0.017280000000000007] 10 10
# [0.8159199999999999, 0.7204400000000002, 0.5975400000000001, 0.48926, 0.2519600000000001, 0.13055, 0.0605, 0.04799999999999999, 0.03020000000000006, 0.0243000000000001] 10
# ...

# %%
# Out:
# [0.84288333 0.76806    0.70112    0.68912    0.5923     0.4462
#  0.3835     0.18205    0.0919     0.0476    ]
# [0.14568 0.07282 0.04868 0.04105 0.0313  0.0263  0.02    0.024   0.0222
#  0.02225]
# [0.87118 0.75022 0.7026  0.66116 0.6546  0.4884  0.3692  0.0775  0.0797
#  0.0443 ]
# [0.17336 0.07388 0.04526 0.03302 0.03    0.0206  0.0202  0.0182  0.0192
#  0.0171 ]
# [0.81592 0.72044 0.59754 0.48926 0.28    0.14    0.06    0.05    0.03
#  0.0243 ]
# [0.27784 0.05544 0.03206 0.02678 0.02    0.02    0.02    0.02    0.02
#  0.02   ]
# [0.75614 0.60776 0.5079  0.3536  0.191   0.1031  0.0492  0.0374  0.0272
#  0.0207 ]
# [0.2338     0.05214    0.03034    0.02233333 0.0183     0.0183
#  0.0178     0.0169     0.0171     0.0171    ]

# %%
plt.rcParams["font.family"] = "Times New Roman"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
plt.rcParams.update({'font.size': 18})
plt.rcParams["font.family"] = "Times"

plt.plot(percentage[1:], edge_without_rewt[1:], linestyle = 'solid', marker = 'o',markersize=10, label = 'DppEdge');
plt.plot(percentage[1:], node_without_rewt[1:], linestyle = 'dashed', marker = 'v',markersize=10, label = 'DivNet');
plt.legend()
plt.savefig('./without_rewt.png')

# %%
plt.plot(percentage[1:], edge_rewt[1:], linestyle = 'solid', marker = 'o', markersize=10, label = 'DppEdge');
plt.plot(percentage[1:], node_rewt[1:], linestyle = 'dashed', marker = 'v', markersize=10,label = 'DivNet');
plt.legend()
plt.savefig('./rewt.png')

# %%
plt.plot(percentage[1:], edge_dropout_without_rewt[1:], linestyle = 'solid', marker = 'o', markersize=10, label = 'DppEdge');
plt.plot(percentage[1:], node_dropout_without_rewt[1:], linestyle = 'dashed', marker = 'v', markersize=10, label = 'DivNet');
plt.legend()
plt.savefig('./dropout_without_rewt.png')

# %%
plt.plot(percentage[1:], edge_dropout_rewt[1:], linestyle = 'solid', marker = 'o', markersize=10, label = 'DppEdge');
plt.plot(percentage[1:], node_dropout_rewt[1:], linestyle = 'dashed', marker = 'v', markersize=10, label = 'DivNet');
plt.legend()
plt.savefig('./dropout_rewt.png')

# %%
plt.errorbar(percentage[1:], edge_without_rewt[1:], yerr=edge_without_rewt_std[1:], capthick = 1, capsize = 5,
             linestyle = 'solid', fmt = 'o',markersize=8, label = 'DppEdge');
plt.errorbar(percentage[1:], node_without_rewt[1:], yerr=node_without_rewt_std[1:], capthick = 1, capsize = 5,
             linestyle = 'dashed', fmt = 'v',markersize=8, label = 'DivNet');
plt.legend()
plt.savefig('./without_rewt.png')

# %%
plt.errorbar(percentage[1:], edge_rewt[1:],  yerr=edge_rewt_std[1:], capthick = 1, capsize = 5,
                 linestyle = 'solid', marker = 'o', markersize=8, label = 'DppEdge');
plt.errorbar(percentage[1:], node_rewt[1:],  yerr=node_rewt_std[1:], capthick = 1, capsize = 5,
         linestyle = 'dashed', marker = 'v', markersize=8,label = 'DivNet');
plt.legend()
plt.savefig('./rewt.png')

# %%
plt.errorbar(percentage[1:], edge_dropout_without_rewt[1:],  yerr=edge_dropout_without_rewt_std[1:], capthick = 1, capsize = 5,
                 linestyle = 'solid', marker = 'o', markersize=8, label = 'DppEdge');
plt.errorbar(percentage[1:], node_dropout_without_rewt[1:],  yerr=node_dropout_without_rewt_std[1:], capthick = 1, capsize = 5,
         linestyle = 'dashed', marker = 'v', markersize=8,label = 'DivNet');
plt.legend()
plt.savefig('./dropout_without_rewt.png')

# %%
plt.errorbar(percentage[1:], edge_dropout_rewt[1:], yerr=edge_dropout_rewt_std[1:], capthick = 1, capsize = 5,
         linestyle = 'solid', marker = 'o', markersize=8, label = 'DppEdge');
plt.errorbar(percentage[1:], node_dropout_rewt[1:], yerr=edge_dropout_rewt_std[1:], capthick = 1, capsize = 5,
         linestyle = 'dashed', marker = 'v', markersize=8, label = 'DivNet');
plt.legend()
plt.savefig('./dropout_rewt.png')

# %%
percentage[1:]
# Out:
# [10, 15, 20, 30, 40, 50, 60, 70, 80]

# %%
import pandas as pd

# %%
d = pd.DataFrame({'name':[],0:[],15:[],20:[],30:[],40:[]})

# %%
d
# Out:
# Empty DataFrame
# Columns: [name, 0, 15, 20, 30, 40]
# Index: []

# %%
sl = []
means = [ edge_rewt, node_rewt, edge_dropout_rewt, node_dropout_rewt]
stds = [ edge_rewt_std, node_rewt_std, edge_dropout_rewt_std, node_dropout_rewt_std]
for m,s in zip(means,stds):
    tmp=[]
    for i in [1,2,3,4,5]:
        tmp.append(str(round(m[i]*100,1))+'\pm'+str(round(s[i]*100,2)))
    sl.append(tmp)

# %%
sl
# Out:
# [['0.05544\\pm0.001711841114122482',
#   '0.03206\\pm0.001309350984266627',
#   '0.026780000000000005\\pm0.0009195651146058158',
#   '0.02253333333333331\\pm0.0012324321031557347',
#   '0.021049999999999975\\pm0.0005469613027140653'],
#  ['0.07282\\pm0.006462321564267752',
#   '0.048680000000000015\\pm0.0025039169315294704',
#   '0.04105000000000003\\pm0.001884807682497069',
#   '0.031299999999999994\\pm0.0016000000000000458',
#   '0.02629999999999999\\pm9.999999999998899e-05'],
#  ['0.052139999999999964\\pm0.0012289833196589724',
#   '0.030340000000000054\\pm0.0011288932633336138',
#   '0.022333333333333316\\pm0.00046427960923947935',
#   '0.018679999999999985\\pm0.0002785677655437027',
#   '0.017920000000000026\\pm0.00019390719429663181'],
#  ['0.07387999999999999\\pm0.006695491020082106',
#   '0.04525999999999999\\pm0.004421131076998283',
#   '0.03301999999999998\\pm0.0010264501936285034',
#   '0.030000000000000027\\pm0.0',
#   '0.020600000000000063\\pm0.0']]

# %%
sl_rewt = []
means = [ edge_rewt, node_rewt, edge_dropout_rewt, node_dropout_rewt]
stds = [ edge_rewt_std, node_rewt_std, edge_dropout_rewt_std, node_dropout_rewt_std]
for m,s in zip(means,stds):
    tmp=[]
    for i in [1,2,3,4,5]:
        tmp.append(str(round(m[i]*100,1))+r'\pm'+str(round(s[i]*100,2)))
    sl_rewt.append(tmp)

# %%
sl_rewt
# Out:
# [['5.5\\pm0.17', '3.2\\pm0.13', '2.7\\pm0.09', '2.3\\pm0.12', '2.1\\pm0.05'],
#  ['7.3\\pm0.65', '4.9\\pm0.25', '4.1\\pm0.19', '3.0\\pm0.15', '2.6\\pm0.09'],
#  ['5.2\\pm0.12', '3.0\\pm0.11', '2.2\\pm0.05', '1.9\\pm0.03', '1.8\\pm0.02'],
#  ['7.4\\pm0.67', '4.5\\pm0.44', '3.3\\pm0.1', '2.6\\pm0.25', '2.1\\pm0.09']]

# %%
sl_no_rewt = []
means = [ edge_without_rewt, node_without_rewt, edge_dropout_without_rewt, node_dropout_without_rewt]
stds = [ edge_without_rewt_std, node_without_rewt_std, edge_dropout_without_rewt_std, node_dropout_without_rewt_std]
for m,s in zip(means,stds):
    tmp=[]
    for i in [1,2,3,4,5]:
        tmp.append(str(round(m[i]*100,1))+r'\pm'+str(round(s[i]*100,2)))
    sl_no_rewt.append(tmp)
sl_no_rewt
# Out:
# [['72.0\\pm3.14',
#   '59.8\\pm1.31',
#   '48.9\\pm2.93',
#   '25.2\\pm1.77',
#   '13.1\\pm2.19'],
#  ['76.8\\pm3.32',
#   '70.1\\pm4.5',
#   '68.9\\pm6.73',
#   '57.9\\pm1.77',
#   '45.5\\pm2.1'],
#  ['60.8\\pm3.15',
#   '50.8\\pm0.76',
#   '35.4\\pm1.71',
#   '19.8\\pm1.27',
#   '9.6\\pm1.19'],
#  ['75.0\\pm8.19',
#   '70.3\\pm5.69',
#   '66.1\\pm6.02',
#   '54.3\\pm1.88',
#   '48.2\\pm1.22']]

# %%
edge_without_rewt
# Out:
# [0.8159199999999999,
#  0.7204400000000002,
#  0.5975400000000001,
#  0.48926,
#  0.2519600000000001,
#  0.13055,
#  0.0605,
#  0.04799999999999999,
#  0.03020000000000006,
#  0.0243000000000001]

# %%
edge_rewt
# Out:
# [0.27784,
#  0.05544,
#  0.03206,
#  0.026780000000000005,
#  0.02253333333333331,
#  0.021049999999999975,
#  0.020425,
#  0.019949999999999968,
#  0.019699999999999995,
#  0.020450000000000024]
