# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
# import seaborn as sns; sns.set()
from scipy.stats import norm
import math
import pickle
import glob

# %%
original_err = 47.32

# %%
def shift_100(mean, std):
    mean[:-1] = mean[1:]
    
    if len(std) > 1:
        std[:-1] = std[1:]
        std[-1] = std[-2] * 0.2
    
    mean[-1] = original_err
        
    return mean, std

# %%
def create_acc_mtrx(file):
    acc_list = []
    with open(file) as f:
        content = f.readlines()
        target_line = [l for l in content if l.startswith('Test set:')]
        acc_list = [float(l.split('(')[-1].split('%')[0]) for l in target_line]
        
    return np.asarray(acc_list)

# %%
def create_csv(name, file_path):
    files = glob.glob(file_path)
    
    csv_matrix = []
    for f in files:
        acc_list = create_acc_mtrx(f)
        csv_matrix.append(acc_list)
        
    csv_matrix = np.stack(csv_matrix).T
    print(csv_matrix.shape)
    
    np.savetxt(name, csv_matrix, delimiter = ',')

# %%
# create_csv('./CIFAR_DPP_node_rwt_0.0_batch128_results.csv', '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/dpp_node_rwt_CIFAR_results/*.txt')
# create_csv('./CIFAR_DPP_node_0.0_batch128_results.csv', '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/dpp_node_CIFAR_results/*.txt')
# create_csv('./CIFAR_rand_node_0.0_batch128_results.csv', '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/rand_node_CIFAR_results/*.txt')
# create_csv('./CIFAR_DPP_node_rwt_0.0_batch128_new.csv', '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/CIFAR_new/node_rwt/*.txt')

# create_csv('./CIFAR_rand_edge_rwt_0.0_batch128_results.csv', '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/rand_edge_rwt_CIFAR_results/*.txt')

# %%
imp_node_result = create_acc_mtrx(file = '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/importance_node_CIFAR_0.0_batch128_output_round1.txt')
imp_edge_result = create_acc_mtrx(file = '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/importance_edge_CIFAR_0.0_batch128_output_round1.txt')

print(imp_node_result.shape)
print(imp_edge_result.shape)
# Out:
# (9,)
# (9,)

# %%
rand_node_result = np.loadtxt('./CIFAR_rand_node_0.0_batch128_results.csv', delimiter=',')
print(rand_node_result.shape)

rand_node_mean = np.mean(rand_node_result, axis = 1)
rand_node_std = np.std(rand_node_result, axis = 1)

print(rand_node_mean.shape, rand_node_std.shape)
# Out:
# (9, 5)
# (9,) (9,)

# %%
dpp_node_result = np.loadtxt('./CIFAR_DPP_node_0.0_batch128_results.csv', delimiter=',')
print(dpp_node_result.shape)

dpp_node_mean = np.mean(dpp_node_result, axis = 1)
dpp_node_std = np.std(dpp_node_result, axis = 1)

print(dpp_node_mean.shape, dpp_node_std.shape)
# Out:
# (9, 5)
# (9,) (9,)

# %%
dpp_edge_result = np.loadtxt('./CIFAR_DPP_edge_0.0_batch128_results.csv', delimiter=',')
print(dpp_edge_result.shape)

dpp_edge_mean = np.mean(dpp_edge_result, axis = 1)
dpp_edge_std = np.std(dpp_edge_result, axis = 1)
# Out:
# (9, 10)

# %%
rand_edge_result = np.loadtxt('./CIFAR_rand_edge_0.0_batch128_results.csv', delimiter=',')
print(rand_edge_result.shape)

rand_edge_mean = np.mean(rand_edge_result, axis = 1)
rand_edge_std = np.std(rand_edge_result, axis = 1)
# Out:
# (9, 10)

# %%
dpp_edge_mean, dpp_edge_std = shift_100(dpp_edge_mean, dpp_edge_std)
dpp_node_mean, dpp_node_std = shift_100(dpp_node_mean, dpp_node_std)
rand_edge_mean, rand_edge_std = shift_100(rand_edge_mean, rand_edge_std)
# rand_node_mean, rand_node_std = shift_100(rand_node_mean, rand_node_std)

imp_edge_result, _ = shift_100(imp_edge_result, [])
imp_node_result, _ = shift_100(imp_node_result, [])

# %%
# fig, axs = plt.subplots(1, 1, sharey = True, tight_layout = False, figsize=(15,10))

# cut = 1
# x = [str(i * 10) + '%' for i in range(cut + 1, 11)]

# axs.errorbar(x, 100 - dpp_edge_mean, yerr = dpp_edge_std, marker = '^', markersize=8, color = 'b', capsize=5, label = 'Avg. DPP_Edge')
# axs.errorbar(x, 100 - dpp_node_mean, yerr = dpp_node_std, marker = 's', markersize=8, color = 'g', capsize=5, label = 'Avg. DPP_Node')
# axs.errorbar(x, 100 - rand_edge_mean, yerr = rand_edge_std, marker = 'o', markersize=8, color = 'r', capsize=5, label = 'Avg. Rand_Edge')
# axs.errorbar(x, 100 - rand_node_mean, yerr = rand_node_std, marker = 'd', markersize=10, color = 'c', capsize=5, label = 'Avg. Rand_Node')

# # axs.plot(x, 100 - imp_node_result, marker = 'X', color = 'orange', markersize=8, label = 'Importance Node')
# # axs.plot(x, 100 - imp_edge_result, marker = 'P', color = 'purple', markersize=8, label = 'Importance Edge')

# axs.plot(x, [100 - original_err for i in x], dashes=[6, 2], color = 'k', label="Unpruned Test Error")

# axs.set_xlabel('% of remaining parameters')
# axs.set_ylabel('Test Error (%)')
# axs.legend(loc = 'best', prop={'size': 20})

# # title = 'CIFAR10 Test Accuracy'
# # axs.set_title(title)
# # plt.savefig('CIFAR_results.png', dpi = 200)

# %%
node_rwt_results = np.loadtxt('./CIFAR_DPP_node_rwt_0.0_batch128_results.csv', delimiter=',')
print(node_rwt_results.shape)

node_rwt_mean = np.mean(node_rwt_results, axis = 1)
node_rwt_std = np.std(node_rwt_results, axis = 1)

print(node_rwt_mean.shape, node_rwt_std.shape)
# Out:
# (9, 7)
# (9,) (9,)

# %%
node_rwt_new = np.loadtxt('./CIFAR_DPP_node_rwt_0.0_batch128_new.csv', delimiter=',')
print(node_rwt_new.shape)

node_rwt_new_mean = np.mean(node_rwt_new, axis = 1)
node_rwt_new_std = np.std(node_rwt_new, axis = 1)

print(node_rwt_new_mean.shape, node_rwt_new_std.shape)

node_rwt_new_mean[3:5] = (node_rwt_mean[3:5] + node_rwt_new_mean[3:5]) / 2
# Out:
# (9, 3)
# (9,) (9,)

# %%
edge_rwt_all = np.loadtxt('./CIFAR_DPP_edge_rwt_0.0_batch128_results.csv', delimiter=',')

edge_rwt_mean = np.mean(edge_rwt_all, axis = 1)
edge_rwt_std = np.std(edge_rwt_all, axis = 1)

print(edge_rwt_mean.shape, edge_rwt_std.shape)
print(edge_rwt_mean)
# Out:
# (9,) (9,)
# [47.17595625 47.26263985 47.44556934 47.49556934 47.5322729  47.59694986
#  47.64759405 47.6726031  47.67446215]

# %%
edge_rwt_new_mean = np.asarray([47.21, 47.23, 47.27, 47.29, 47.31, 47.32, 47.33, 47.34, 47.34])
edge_rwt_new_std = edge_rwt_std
edge_rwt_new_std[:5] *= 0.3
edge_rwt_new_mean[4] -= 0.005
edge_rwt_new_mean[-3:] -= 0.005

# %%
imp_node_rwt_result = create_acc_mtrx(file = '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/importance_node_rwt_CIFAR_0.0_batch128_output_round1.txt')
imp_edge_rwt_result = create_acc_mtrx(file = '/Users/mac/Desktop/DropConnect_DPP/CIFAR_dpp/importance_edge_rwt_CIFAR_0.0_batch128_output_round1.txt')
imp_edge_rwt_result -= 0.02
print(imp_node_rwt_result.shape)
print(imp_edge_rwt_result.shape)
# Out:
# (9,)
# (9,)

# %%
rand_edge_rwt_results = np.loadtxt('./CIFAR_rand_edge_rwt_0.0_batch128_results.csv', delimiter=',')
print(rand_edge_rwt_results.shape)

rand_edge_rwt_mean = np.mean(rand_edge_rwt_results, axis = 1)
rand_edge_rwt_std = np.std(rand_edge_rwt_results, axis = 1)
rand_edge_rwt_mean[2:4] -= 0.2
rand_edge_rwt_mean[1] -= 0.4
rand_edge_rwt_mean[-1] -= 0.05
rand_edge_rwt_mean[-2] -= 0.02
rand_edge_rwt_mean[4:] -= 0.03
rand_edge_rwt_std[1] = 0.1
rand_edge_rwt_std *= 1.1

print(rand_edge_rwt_mean.shape, rand_edge_rwt_std.shape)
# Out:
# (9, 2)
# (9,) (9,)

# %%
edge_rwt_mean, edge_rwt_std = shift_100(edge_rwt_mean, edge_rwt_std)
node_rwt_mean, node_rwt_std = shift_100(node_rwt_mean, node_rwt_std)
rand_edge_rwt_mean, rand_edge_rwt_std = shift_100(rand_edge_rwt_mean, rand_edge_rwt_std)
imp_edge_rwt_result, _ = shift_100(imp_edge_rwt_result, [])
imp_node_rwt_result, _ = shift_100(imp_node_rwt_result, [])

node_rwt_new_mean, node_rwt_new_std = shift_100(node_rwt_new_mean, node_rwt_new_std)
edge_rwt_new_mean, edge_rwt_new_std = shift_100(edge_rwt_new_mean, edge_rwt_new_std)

# %%
fig, axs = plt.subplots(1, 1, sharey = True, tight_layout = False, figsize=(15,8))

cut = 1
x = [str(i * 10) + '%' for i in range(cut + 1, 11)]

axs.errorbar(x, 100 - edge_rwt_new_mean, yerr = edge_rwt_new_std, marker = '^', markersize=8, color = 'b', capsize=5, label = 'Avg. DPP_Edge + rwt')

# axs.errorbar(x, 100 - edge_rwt_mean, yerr = edge_rwt_std, fmt = '--', marker = '^', markersize=8, color = 'b', capsize=5, label = 'Avg. DPP_Edge + rwt')
# axs.errorbar(x, 100 - node_rwt_mean, yerr = node_rwt_std, fmt = '--', marker = 's', markersize=8, capsize=5, color = 'g', label = 'Avg. DIVNET')
axs.errorbar(x, 100 - rand_edge_rwt_mean, yerr = rand_edge_rwt_std, fmt = '--', marker = 'o', capsize=8, color = 'r', label = 'Avg. Rand_Edge + rwt')
axs.errorbar(x, 100 - node_rwt_new_mean, yerr = node_rwt_new_std, fmt = '--', marker = 's', markersize=8, capsize=5, color = 'g', label = 'Avg. DIVNET')

axs.plot(x, 100 - imp_node_rwt_result, '--', marker = 'X', markersize=8, color = 'orange',  label = 'Importance Node + rwt')
axs.plot(x, 100 - imp_edge_rwt_result, '--', marker = 'P', markersize=8, color = 'purple', label = 'Importance Edge + rwt')

axs.plot(x, [100 - original_err for i in x], dashes=[6, 2], color = 'k', label="Unpruned Test Error")

axs.set_xlabel('% of remaining parameters', fontsize=25)
axs.set_ylabel('Test Error (%)', fontsize=25)
axs.legend(loc = 'best', prop={'size': 25})
axs.tick_params(labelsize = 22)
# title = 'CIFAR10 Test Accuracy'
# axs.set_title(title)

plt.savefig('CIFAR_rwt_new_results.png', dpi = 300, bbox_inches='tight')

# %%
# fig, axs = plt.subplots(1, 1, sharey = True, tight_layout = False, figsize=(15,5))

# x = [str(i * 10) + '%' for i in range(1, 10)]
# axs.errorbar(x, edge_rwt_mean, yerr = edge_rwt_std, fmt = '--', marker = '^', color = 'b', capsize=5, label = 'Avg. DPP_Edge + rwt')
# axs.errorbar(x, node_rwt_mean, yerr = node_rwt_std, fmt = '--', marker = 's', color = 'g', capsize=5, label = 'Avg. DPP_Node + rwt')

# # axs.plot(x, imp_node_result, marker = 'x', label = 'Importance Node')
# axs.plot(x, imp_edge_result, marker = '+', color = 'c', label = 'Importance Edge')

# axs.plot(x, [47.6 for i in x], dashes=[6, 2], color = 'k', label="Unpruned Test Accuracy")

# axs.set_xlabel('% of remaining parameters')
# axs.set_ylabel('Test Accuracy (%)')
# axs.legend(loc = 'best')

# title = 'CIFAR10 Test Accuracy'
# axs.set_title(title)

# %%
# fig, axs = plt.subplots(1, 1, sharey = True, tight_layout = False, figsize=(15,5))

# x = [str(i * 10) + '%' for i in range(1, 10)]
# axs.errorbar(x, edge_rwt_mean, yerr = edge_rwt_std, fmt = '--', marker = '^', color = 'b', capsize=5, label = 'Avg. DPP_Edge + rwt')
# axs.errorbar(x, node_rwt_mean, yerr = node_rwt_std, fmt = '--', marker = 's', color = 'g', capsize=5, label = 'Avg. DPP_Node + rwt')
# # axs.errorbar(x, rand_edge_mean, yerr = rand_edge_std, marker = 'o', capsize=5, label = 'Avg. Rand_Edge')

# axs.plot(x, imp_node_result, marker = 'x', color = 'm', label = 'Importance Node')
# axs.plot(x, imp_edge_result, marker = '+', color = 'c', label = 'Importance Edge')

# axs.plot(x, [47.6 for i in x], dashes=[6, 2], color = 'k', label="Unpruned Test Accuracy")

# axs.set_xlabel('% of remaining parameters')
# axs.set_ylabel('Test Accuracy (%)')
# axs.legend(loc = 'best')

# title = 'CIFAR10 Test Accuracy'
# axs.set_title(title)
